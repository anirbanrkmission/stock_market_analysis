# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
wipro_daywise = pd.read_csv("C:/Users/Anirban/Documents/dataset_daywise/wipro_daywise.csv")

# %%
def curvedivision(yi):
    x = wipro_daywise['Date']
    dif = yi.max() - yi.min()
    y1 = dif//3
    y2 = (dif*2)//3
    y0 = yi.loc[wipro_daywise['Date'] == wipro_daywise['Date'].min()]
    plt.figure()
    ax =yi.plot(figsize=(50,30))
    ax.axhline(y=y1,xmin=0,xmax=len(x),color='g',linestyle='--',lw=3)
    ax.axhline(y=y2,xmin=0,xmax=len(x),color='b',linestyle='--',lw=3)
    ax.axhline(y=float(y0),xmin=0,xmax=len(x),color='r',linestyle='--',lw=3)
    plt.show()

# %%
def area(): #defination will be given shortly
    x =

# %%
curvedivision(wipro_daywise['Spread High-Low'])

# %%
wipro_daywise.columns
# Out:
# Index(['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
wipro_daywise['Open Price'].loc[wipro_daywise['Date'] == wipro_daywise['Date'].min()]
# Out:
# 3584    1361.5
# Name: Open Price, dtype: float64

# %%
type(wipro_daywise['Open Price'].loc[wipro_daywise['Date'] == wipro_daywise['Date'].min()])
# Out:
# pandas.core.series.Series

# %%
wipro_daywise['Open Price'][0]
# Out:
# 300.0
